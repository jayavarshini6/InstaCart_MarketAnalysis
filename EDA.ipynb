# %% [markdown]
# ### Exploratory Data Analysis

# %%
pip install wordcloud
# Out:
# Collecting wordcloud
#   Downloading wordcloud-1.9.2-cp310-cp310-win_amd64.whl (152 kB)
#      -------------------------------------- 152.1/152.1 kB 3.0 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib in c:\users\jayav\anaconda3\lib\site-packages (from wordcloud) (3.7.0)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\jayav\anaconda3\lib\site-packages (from wordcloud) (1.23.5)
# Requirement already satisfied: pillow in c:\users\jayav\anaconda3\lib\site-packages (from wordcloud) (9.4.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\jayav\anaconda3\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\jayav\anaconda3\lib\site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\jayav\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\jayav\anaconda3\lib\site-packages (from matplotlib->wordcloud) (22.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\jayav\anaconda3\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\jayav\anaconda3\lib\site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\jayav\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.0.5)
# Requirement already satisfied: six>=1.5 in c:\users\jayav\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.9.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %%
df = pd.read_csv('./tweetdocs1.csv')
df.head()
# Out:
#                                               tokens labels
# 0  ['gas', 'house', 'hit', 'i am', 'going', 'chap...    pos
# 1  ['theo', 'walcott', 'still', 'shit', 'watch', ...    neg
# 2  ['i am', 'gsp', 'fan', 'hate', 'nick', 'diaz',...    neg
# 3  ['iranian', 'general', 'say', 'israel is', 'ir...    neg
# 4  ['j', 'davlar', 'main', 'rival', 'team', 'pola...    pos

# %%
df.shape
# Out:
# (8208, 2)

# %%
np.sum(df.isna())
# Out:
# tokens    0
# labels    0
# dtype: int64

# %%
df.count()
# Out:
# tokens    8208
# labels    8208
# dtype: int64

# %%
df['labels'].value_counts()
# Out:
# neu    3942
# pos    3059
# neg    1207
# Name: labels, dtype: int64

# %%
plt.hist(df['labels'])
# Out:
# (array([3059.,    0.,    0.,    0.,    0., 1207.,    0.,    0.,    0.,
#         3942.]),
#  array([0. , 0.2, 0.4, 0.6, 0.8, 1. , 1.2, 1.4, 1.6, 1.8, 2. ]),
#  <BarContainer object of 10 artists>)

# %%
text = ' '.join(df['tokens'])

wordcloud = WordCloud(width=800, height=800).generate(text)

plt.figure(figsize=(10, 10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()
